# %% [markdown]
# ## Import dependencies

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import ast 
from scipy import stats
from ast import literal_eval
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity
from sklearn.model_selection import train_test_split

import warnings; warnings.simplefilter('ignore')

# %% [markdown]
# ## Load dataset

# %%
# !ls naukri_com-job_sample.csv
# Out:
# naukri_com-job_sample.csv

# %%
data = pd.read_csv('naukri_com-job_sample.csv')

# %%
data.head()
# Out:
#                                       company  \
# 0                            MM Media Pvt Ltd
# 1                          find live infotech
# 2         Softtech Career Infosystem Pvt. Ltd
# 3                      Onboard HRServices LLP
# 4  Spire Technologies and Solutions Pvt. Ltd.
#
#                                            education   experience  \
# 0  UG: B.Tech/B.E. - Any Specialization PG:Any Po...    0 - 1 yrs
# 1  UG: B.Tech/B.E. - Any Specialization PG:MBA/PG...    0 - 0 yrs
# 2  UG: Any Graduate - Any Specialization PG:Any P...    4 - 8 yrs
# 3  UG: Any Graduate - Any Specialization PG:CA Do...  11 - 15 yrs
# 4  UG: B.Tech/B.E. - Any Specialization PG:Any Po...    6 - 8 yrs
#
#                                    industry  \
# 0          Media / Entertainment / Internet
# 1  Advertising / PR / MR / Event Management
# 2           IT-Software / Software Services
# 3    Banking / Financial Services / Broking
# 4           IT-Software / Software Services
#
#                                       jobdescription         jobid  \
# 0  Job Description   Send me Jobs like this Quali...  210516002263
# 1  Job Description   Send me Jobs like this Quali...  210516002391
# 2  Job Description   Send me Jobs like this - as ...  101016900534
# 3  Job Description   Send me Jobs like this - Inv...   81016900536
# 4  Job Description   Send me Jobs like this Pleas...  120916002122
#
#                                  joblocation_address  \
# 0                                            Chennai
# 1                                            Chennai
# 2                                          Bengaluru
# 3  Mumbai, Bengaluru, Kolkata, Chennai, Coimbator...
# 4                                          Bengaluru
#
#                                    jobtitle  numberofpositions  \
# 0  Walkin Data Entry Operator (night Shift)                NaN
# 1        Work Based Onhome Based Part Time.               60.0
# 2                    Pl/sql Developer - SQL                NaN
# 3    Manager/ad/partner - Indirect Tax - CA                NaN
# 4           JAVA Technical Lead (6-8 yrs) -                4.0
#
#                           payrate                   postdate site_name  \
# 0         1,50,000 - 2,25,000 P.A  2016-05-21 19:30:00 +0000       NaN
# 1  1,50,000 - 2,50,000 P.A. 20000  2016-05-21 19:30:00 +0000       NaN
# 2      Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000       NaN
# 3      Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000       NaN
# 4      Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000       NaN
#
#                                   skills                           uniq_id
# 0                                   ITES  43b19632647068535437c774b6ca6cf8
# 1                              Marketing  d4c72325e57f89f364812b5ed5a795f0
# 2  IT Software - Application Programming  c47df6f4cfdf5b46f1fd713ba61b9eba
# 3                               Accounts  115d28f140f694dd1cc61c53d03c66ae
# 4  IT Software - Application Programming  a12553fc03bc7bcced8b1bb8963f97b4

# %%
data.columns
# Out:
# Index(['company', 'education', 'experience', 'industry', 'jobdescription',
#        'jobid', 'joblocation_address', 'jobtitle', 'numberofpositions',
#        'payrate', 'postdate', 'site_name', 'skills', 'uniq_id'],
#       dtype='object')

# %%
data.shape
# Out:
# (22000, 14)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22000 entries, 0 to 21999
# Data columns (total 14 columns):
# company                21996 non-null object
# education              20004 non-null object
# experience             21996 non-null object
# industry               21995 non-null object
# jobdescription         21996 non-null object
# jobid                  22000 non-null int64
# joblocation_address    21499 non-null object
# jobtitle               22000 non-null object
# numberofpositions      4464 non-null float64
# payrate                21903 non-null object
# postdate               21977 non-null object
# site_name              3987 non-null object
# skills                 21472 non-null object
# uniq_id                22000 non-null object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 2.3+ MB

# %% [markdown]
# ## Pre-processing data

# %%
df = data[data['industry'] == "IT-Software / Software Services"]

# %%
df
# Out:
#                                                  company  \
# 2                    Softtech Career Infosystem Pvt. Ltd
# 4             Spire Technologies and Solutions Pvt. Ltd.
# 5                        PFS Web Global Services Pvt Ltd
# 6                 Kinesis Management Consultant Pvt. Ltd
# 9                                              Accenture
# ...                                                  ...
# 21990  Link Tree Technologies PVT LTD hiring for CMM ...
# 21992                                       Confidential
# 21996   Careernet Technologies Pvt Ltd hiring for Client
# 21998                                       Confidential
# 21999                    Cambio Consulting India Pvt Ltd
#
#                                                education   experience  \
# 2      UG: Any Graduate - Any Specialization PG:Any P...    4 - 8 yrs
# 4      UG: B.Tech/B.E. - Any Specialization PG:Any Po...    6 - 8 yrs
# 5      UG: B.Tech/B.E. - Any Specialization PG:MCA - ...    2 - 5 yrs
# 6                                                    NaN    1 - 3 yrs
# 9      UG: Any Graduate - Any Specialization PG:Any P...    1 - 5 yrs
# ...                                                  ...          ...
# 21990  UG: Any Graduate - Any Specialization PG:Post ...   7 - 12 yrs
# 21992  UG: Any Graduate - Any Specialization Doctorat...  12 - 18 yrs
# 21996  UG: B.Tech/B.E. - Any Specialization PG:M.Tech...    3 - 5 yrs
# 21998  UG: B.Tech/B.E. - Any Specialization PG:MCA - ...   7 - 12 yrs
# 21999  UG: B.Tech/B.E. - Any Specialization PG:MCA - ...   5 - 10 yrs
#
#                               industry  \
# 2      IT-Software / Software Services
# 4      IT-Software / Software Services
# 5      IT-Software / Software Services
# 6      IT-Software / Software Services
# 9      IT-Software / Software Services
# ...                                ...
# 21990  IT-Software / Software Services
# 21992  IT-Software / Software Services
# 21996  IT-Software / Software Services
# 21998  IT-Software / Software Services
# 21999  IT-Software / Software Services
#
#                                           jobdescription         jobid  \
# 2      Job Description   Send me Jobs like this - as ...  101016900534
# 4      Job Description   Send me Jobs like this Pleas...  120916002122
# 5      Job Description   Send me Jobs like this We ar...  131016005070
# 6      Job Description   Send me Jobs like this exper...  131016004451
# 9      Job Description   Send me Jobs like this Overa...  121016901354
# ...                                                  ...           ...
# 21990  Job Description   Send me Jobs like this Looki...  261116001071
# 21992  Job Description   Send me Jobs like this Solut...  261116900077
# 21996  Job Description   Send me Jobs like this Looki...  241116001104
# 21998  Job Description   Send me Jobs like this We ar...  231116901329
# 21999  Job Description   Send me Jobs like this Job d...  251116003840
#
#                                      joblocation_address  \
# 2                                              Bengaluru
# 4                                              Bengaluru
# 5                                              Bengaluru
# 6      Delhi NCR, Mumbai, Bengaluru, Kochi, Greater N...
# 9                                              Bengaluru
# ...                                                  ...
# 21990                                          Bengaluru
# 21992                                          Bengaluru
# 21996                                 Bengaluru, Gurgaon
# 21998                               Delhi NCR, Bengaluru
# 21999                                          Bengaluru
#
#                                                 jobtitle  numberofpositions  \
# 2                                 Pl/sql Developer - SQL                NaN
# 4                        JAVA Technical Lead (6-8 yrs) -                4.0
# 5      WALK IN - As400 Developer - Pfsweb Global Serv...                NaN
# 6                                          PHP Developer                2.0
# 9                                      German Translator                NaN
# ...                                                  ...                ...
# 21990   Urgent Placement for SAP ABAP with HCL Bangalore                NaN
# 21992                        Advisory Solution Architect                NaN
# 21996      Java Backend Developers for a Product Company                NaN
# 21998  Sr UI Developer/ Technical Lead - Html/ CSS/ J...                NaN
# 21999                              RF Firmware Engineers                NaN
#
#                           payrate                   postdate       site_name  \
# 2      Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000             NaN
# 4      Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000             NaN
# 5      Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000             NaN
# 6         3,00,000 - 6,50,000 P.A  2016-10-13 16:20:55 +0000             NaN
# 9      Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000             NaN
# ...                           ...                        ...             ...
# 21990  Not Disclosed by Recruiter  2016-11-25 22:47:05 +0000  www.naukri.com
# 21992  Not Disclosed by Recruiter  2016-11-25 22:47:05 +0000  www.naukri.com
# 21996    8,50,000 - 14,00,000 P.A  2016-11-24 22:47:05 +0000  www.naukri.com
# 21998  Not Disclosed by Recruiter  2016-11-27 22:47:05 +0000  www.naukri.com
# 21999   12,00,000 - 22,00,000 P.A  2016-11-25 22:47:05 +0000  www.naukri.com
#
#                                       skills                           uniq_id
# 2      IT Software - Application Programming  c47df6f4cfdf5b46f1fd713ba61b9eba
# 4      IT Software - Application Programming  a12553fc03bc7bcced8b1bb8963f97b4
# 5      IT Software - Application Programming  8c3af9062ea835b0965779e2c7faac76
# 6      IT Software - Application Programming  98f84958cd6409386e7f0c9e447b8510
# 9                                       ITES  7774df1c672c0b92486da8b36a721638
# ...                                      ...                               ...
# 21990  IT Software - Application Programming  9810d3c9e451e7374871ec1927d59111
# 21992  IT Software - Application Programming  0eb70f84a1d491fb2ad7332241475741
# 21996  IT Software - Application Programming  acb80b7bb109fa76d22d1f11c6e16c6a
# 21998  IT Software - Application Programming  c6f6538cb1007dd02c1b4b77909b3d38
# 21999       IT Software - System Programming  74fec26df6e1c0be0171311a2f03f180
#
# [9216 rows x 14 columns]

# %%
df.shape
# Out:
# (9216, 14)

# %%
replacements = {
   'joblocation_address': {
      r'(Bengaluru/Bangalore)': 'Bangalore',
      r'Bengaluru': 'Bangalore',
      r'Hyderabad / Secunderabad': 'Hyderabad',
      r'Mumbai , Mumbai': 'Mumbai',
      r'Noida': 'NCR',
      r'Delhi': 'NCR',
      r'Gurgaon': 'NCR', 
      r'Delhi/NCR(National Capital Region)': 'NCR',
      r'Delhi , Delhi': 'NCR',
      r'Noida , Noida/Greater Noida': 'NCR',
      r'Ghaziabad': 'NCR',
      r'Delhi/NCR(National Capital Region) , Gurgaon': 'NCR',
      r'NCR , NCR': 'NCR',
      r'NCR/NCR(National Capital Region)': 'NCR',
      r'NCR , NCR/Greater NCR': 'NCR',
      r'NCR/NCR(National Capital Region) , NCR': 'NCR', 
      r'NCR , NCR/NCR(National Capital Region)': 'NCR', 
      r'Bangalore , Bangalore / Bangalore': 'Bangalore',
      r'Bangalore , karnataka': 'Bangalore',
      r'NCR/NCR(National Capital Region)': 'NCR',
      r'NCR/Greater NCR': 'NCR',
      r'NCR/NCR(National Capital Region) , NCR': 'NCR'
       
   }
}

df.replace(replacements, regex=True, inplace=True)

# %%
df['split'] = np.random.randn(df.shape[0], 1)

msk = np.random.rand(len(df)) <= 0.7

train = df[msk]
test = df[~msk]

# %%
train
# Out:
#                                                  company  \
# 2                    Softtech Career Infosystem Pvt. Ltd
# 4             Spire Technologies and Solutions Pvt. Ltd.
# 5                        PFS Web Global Services Pvt Ltd
# 9                                              Accenture
# 11           Convate hiring for Retail/e-commerce domain
# ...                                                  ...
# 21986                                Peopleton Solutions
# 21988                  Microsoft India (R and D) Pvt Ltd
# 21990  Link Tree Technologies PVT LTD hiring for CMM ...
# 21992                                       Confidential
# 21999                    Cambio Consulting India Pvt Ltd
#
#                                                education   experience  \
# 2      UG: Any Graduate - Any Specialization PG:Any P...    4 - 8 yrs
# 4      UG: B.Tech/B.E. - Any Specialization PG:Any Po...    6 - 8 yrs
# 5      UG: B.Tech/B.E. - Any Specialization PG:MCA - ...    2 - 5 yrs
# 9      UG: Any Graduate - Any Specialization PG:Any P...    1 - 5 yrs
# 11                 UG: Any Graduate - Any Specialization    4 - 8 yrs
# ...                                                  ...          ...
# 21986  UG: B.Tech/B.E. - Any Specialization PG:MCA - ...    4 - 9 yrs
# 21988  UG: B.Tech/B.E. - Computers PG:MS/M.Sc(Science...    6 - 7 yrs
# 21990  UG: Any Graduate - Any Specialization PG:Post ...   7 - 12 yrs
# 21992  UG: Any Graduate - Any Specialization Doctorat...  12 - 18 yrs
# 21999  UG: B.Tech/B.E. - Any Specialization PG:MCA - ...   5 - 10 yrs
#
#                               industry  \
# 2      IT-Software / Software Services
# 4      IT-Software / Software Services
# 5      IT-Software / Software Services
# 9      IT-Software / Software Services
# 11     IT-Software / Software Services
# ...                                ...
# 21986  IT-Software / Software Services
# 21988  IT-Software / Software Services
# 21990  IT-Software / Software Services
# 21992  IT-Software / Software Services
# 21999  IT-Software / Software Services
#
#                                           jobdescription         jobid  \
# 2      Job Description   Send me Jobs like this - as ...  101016900534
# 4      Job Description   Send me Jobs like this Pleas...  120916002122
# 5      Job Description   Send me Jobs like this We ar...  131016005070
# 9      Job Description   Send me Jobs like this Overa...  121016901354
# 11     Job Description   Send me Jobs like this Greet...   61016003187
# ...                                                  ...           ...
# 21986  Job Description   Send me Jobs like this Stron...  261116002974
# 21988  Job Description   Send me Jobs like this Job D...  241116901005
# 21990  Job Description   Send me Jobs like this Looki...  261116001071
# 21992  Job Description   Send me Jobs like this Solut...  261116900077
# 21999  Job Description   Send me Jobs like this Job d...  251116003840
#
#       joblocation_address                                           jobtitle  \
# 2               Bangalore                             Pl/sql Developer - SQL
# 4               Bangalore                    JAVA Technical Lead (6-8 yrs) -
# 5               Bangalore  WALK IN - As400 Developer - Pfsweb Global Serv...
# 9               Bangalore                                  German Translator
# 11              Bangalore    Opening for Android Developer-bangalore-4-8 yrs
# ...                   ...                                                ...
# 21986      Bangalore, NCR        SDE 2 (contact at Priyank.pal@peopleton.in)
# 21988           Bangalore                                               SDE2
# 21990           Bangalore   Urgent Placement for SAP ABAP with HCL Bangalore
# 21992           Bangalore                        Advisory Solution Architect
# 21999           Bangalore                              RF Firmware Engineers
#
#        numberofpositions                                    payrate  \
# 2                    NaN                 Not Disclosed by Recruiter
# 4                    4.0                 Not Disclosed by Recruiter
# 5                    NaN                 Not Disclosed by Recruiter
# 9                    NaN                 Not Disclosed by Recruiter
# 11                   NaN                 Not Disclosed by Recruiter
# ...                  ...                                        ...
# 21986                NaN  15,00,000 - 30,00,000 P.A. Salary is open
# 21988                NaN                 Not Disclosed by Recruiter
# 21990                NaN                 Not Disclosed by Recruiter
# 21992                NaN                 Not Disclosed by Recruiter
# 21999                NaN                  12,00,000 - 22,00,000 P.A
#
#                         postdate       site_name  \
# 2      2016-10-13 16:20:55 +0000             NaN
# 4      2016-10-13 16:20:55 +0000             NaN
# 5      2016-10-13 16:20:55 +0000             NaN
# 9      2016-10-13 16:20:55 +0000             NaN
# 11     2016-10-13 16:20:55 +0000             NaN
# ...                          ...             ...
# 21986  2016-11-25 22:47:05 +0000  www.naukri.com
# 21988  2016-11-25 22:47:05 +0000  www.naukri.com
# 21990  2016-11-25 22:47:05 +0000  www.naukri.com
# 21992  2016-11-25 22:47:05 +0000  www.naukri.com
# 21999  2016-11-25 22:47:05 +0000  www.naukri.com
#
#                                       skills  \
# 2      IT Software - Application Programming
# 4      IT Software - Application Programming
# 5      IT Software - Application Programming
# 9                                       ITES
# 11     IT Software - Application Programming
# ...                                      ...
# 21986                IT Software - eCommerce
# 21988                IT Software - eCommerce
# 21990  IT Software - Application Programming
# 21992  IT Software - Application Programming
# 21999       IT Software - System Programming
#
#                                 uniq_id     split
# 2      c47df6f4cfdf5b46f1fd713ba61b9eba  0.647748
# 4      a12553fc03bc7bcced8b1bb8963f97b4 -0.114305
# 5      8c3af9062ea835b0965779e2c7faac76 -0.638890
# 9      7774df1c672c0b92486da8b36a721638 -0.266100
# 11     2657f737cb46cf289a05d6577a746976 -0.878506
# ...                                 ...       ...
# 21986  ca542ff8b113744468b677f061bde0ec -0.169210
# 21988  a225337270ab5f885ee8af83e7b04865  1.172678
# 21990  9810d3c9e451e7374871ec1927d59111 -1.368424
# 21992  0eb70f84a1d491fb2ad7332241475741  1.138126
# 21999  74fec26df6e1c0be0171311a2f03f180  1.044336
#
# [6387 rows x 15 columns]

# %%
test
# Out:
#                                                  company  \
# 6                 Kinesis Management Consultant Pvt. Ltd
# 23                                        OKDA Solutions
# 28     Careernet Technologies Pvt Ltd hiring for A US...
# 30          The HRism hiring for US based Product Client
# 37                       SLK Software Services Pvt. Ltd.
# ...                                                  ...
# 21945  Career Trackers and Consulting hiring for A ve...
# 21955                    Cambio Consulting India Pvt Ltd
# 21968                                          HR ACCESS
# 21996   Careernet Technologies Pvt Ltd hiring for Client
# 21998                                       Confidential
#
#                                                education   experience  \
# 6                                                    NaN    1 - 3 yrs
# 23                 UG: Any Graduate - Any Specialization   6 - 10 yrs
# 28     UG: B.Tech/B.E. - Any Specialization PG:M.Tech...    3 - 6 yrs
# 30     UG: Any Graduate - Any Specialization PG:Any P...    3 - 7 yrs
# 37     UG: B.Tech/B.E. - Computers PG:Post Graduation...    3 - 5 yrs
# ...                                                  ...          ...
# 21945  UG: Any Graduate, Graduation Not Required PG:A...   5 - 10 yrs
# 21955                                                NaN   6 - 11 yrs
# 21968  UG: B.Tech/B.E. - Any Specialization PG:MBA/PG...  10 - 14 yrs
# 21996  UG: B.Tech/B.E. - Any Specialization PG:M.Tech...    3 - 5 yrs
# 21998  UG: B.Tech/B.E. - Any Specialization PG:MCA - ...   7 - 12 yrs
#
#                               industry  \
# 6      IT-Software / Software Services
# 23     IT-Software / Software Services
# 28     IT-Software / Software Services
# 30     IT-Software / Software Services
# 37     IT-Software / Software Services
# ...                                ...
# 21945  IT-Software / Software Services
# 21955  IT-Software / Software Services
# 21968  IT-Software / Software Services
# 21996  IT-Software / Software Services
# 21998  IT-Software / Software Services
#
#                                           jobdescription         jobid  \
# 6      Job Description   Send me Jobs like this exper...  131016004451
# 23     Job Description   Send me Jobs like this Job D...  110116900920
# 28     Job Description   Send me Jobs like this Posit...  121016004415
# 30     Job Description   Send me Jobs like this Candi...  131016007104
# 37     Job Description   Send me Jobs like this Job P...  121016901125
# ...                                                  ...           ...
# 21945  Job Description   Send me Jobs like this We ha...   70916000307
# 21955  Job Description   Send me Jobs like this Job D...  251116006262
# 21968  Job Description   Send me Jobs like this The A...  251116900026
# 21996  Job Description   Send me Jobs like this Looki...  241116001104
# 21998  Job Description   Send me Jobs like this We ar...  231116901329
#
#                                      joblocation_address  \
# 6      NCR NCR, Mumbai, Bangalore, Kochi, Greater NCR...
# 23                                             Bangalore
# 28                                             Bangalore
# 30                            Ahmedabad, Bangalore, Pune
# 37                                             Bangalore
# ...                                                  ...
# 21945                            Bangalore, Pune, Mumbai
# 21955                Bangalore, Hyderabad, Chennai, Pune
# 21968                                          Bangalore
# 21996                                     Bangalore, NCR
# 21998                                 NCR NCR, Bangalore
#
#                                                 jobtitle  numberofpositions  \
# 6                                          PHP Developer                2.0
# 23                Sr iOS Developer - Objective C / Cocoa                NaN
# 28      Senio QA with a Product Based Startup, Bangalore                NaN
# 30     Test Automation Engineer ( Selenium + API Test...                2.0
# 37                                   Senior Developer-bi                NaN
# ...                                                  ...                ...
# 21945  Network Security Specialist for Pune, Mumbai &...               10.0
# 21955        Java/j2ee with Spring Architects--bangalore                NaN
# 21968  Application Services Global Program Office Lea...                NaN
# 21996      Java Backend Developers for a Product Company                NaN
# 21998  Sr UI Developer/ Technical Lead - Html/ CSS/ J...                NaN
#
#                           payrate                   postdate       site_name  \
# 6         3,00,000 - 6,50,000 P.A  2016-10-13 16:20:55 +0000             NaN
# 23     Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000             NaN
# 28       9,00,000 - 14,00,000 P.A  2016-10-13 16:20:56 +0000             NaN
# 30     Not Disclosed by Recruiter  2016-10-13 16:20:56 +0000             NaN
# 37     Not Disclosed by Recruiter  2016-10-13 16:20:56 +0000             NaN
# ...                           ...                        ...             ...
# 21945        Best In The Industry  2016-11-25 22:47:03 +0000  www.naukri.com
# 21955    8,00,000 - 18,00,000 P.A  2016-11-24 22:47:03 +0000  www.naukri.com
# 21968  Not Disclosed by Recruiter  2016-11-25 22:47:04 +0000  www.naukri.com
# 21996    8,50,000 - 14,00,000 P.A  2016-11-24 22:47:05 +0000  www.naukri.com
# 21998  Not Disclosed by Recruiter  2016-11-27 22:47:05 +0000  www.naukri.com
#
#                                       skills  \
# 6      IT Software - Application Programming
# 23     IT Software - Application Programming
# 28     IT Software - Application Programming
# 30                IT Software - QA & Testing
# 37     IT Software - Application Programming
# ...                                      ...
# 21945   IT Software - Network Administration
# 21955                IT Software - eCommerce
# 21968                                  Sales
# 21996  IT Software - Application Programming
# 21998  IT Software - Application Programming
#
#                                 uniq_id     split
# 6      98f84958cd6409386e7f0c9e447b8510 -0.068122
# 23     bf23fa0322c4af0f4d24ae7241a33d99 -0.751303
# 28     3382a9c15d825cb9382dc5f3a1f99ce3  0.493978
# 30     fb748fb77d37c9cdd15daaa68f77f95a -1.350865
# 37     0f469db6708503116bf996c325047bc1 -1.292006
# ...                                 ...       ...
# 21945  c5a9b84defcce6ec9702743b348fba7b -0.142197
# 21955  25f9b33a61fc19803163399a221d9f05 -1.694985
# 21968  44dcc9527994ac2914af93e38dd85aff  0.490008
# 21996  acb80b7bb109fa76d22d1f11c6e16c6a  0.453978
# 21998  c6f6538cb1007dd02c1b4b77909b3d38  0.359435
#
# [2829 rows x 15 columns]

# %%
test.shape
# Out:
# (2829, 15)

# %%
test.head()
# Out:
#                                               company  \
# 6              Kinesis Management Consultant Pvt. Ltd
# 23                                     OKDA Solutions
# 28  Careernet Technologies Pvt Ltd hiring for A US...
# 30       The HRism hiring for US based Product Client
# 37                    SLK Software Services Pvt. Ltd.
#
#                                             education  experience  \
# 6                                                 NaN   1 - 3 yrs
# 23              UG: Any Graduate - Any Specialization  6 - 10 yrs
# 28  UG: B.Tech/B.E. - Any Specialization PG:M.Tech...   3 - 6 yrs
# 30  UG: Any Graduate - Any Specialization PG:Any P...   3 - 7 yrs
# 37  UG: B.Tech/B.E. - Computers PG:Post Graduation...   3 - 5 yrs
#
#                            industry  \
# 6   IT-Software / Software Services
# 23  IT-Software / Software Services
# 28  IT-Software / Software Services
# 30  IT-Software / Software Services
# 37  IT-Software / Software Services
#
#                                        jobdescription         jobid  \
# 6   Job Description   Send me Jobs like this exper...  131016004451
# 23  Job Description   Send me Jobs like this Job D...  110116900920
# 28  Job Description   Send me Jobs like this Posit...  121016004415
# 30  Job Description   Send me Jobs like this Candi...  131016007104
# 37  Job Description   Send me Jobs like this Job P...  121016901125
#
#                                   joblocation_address  \
# 6   NCR NCR, Mumbai, Bangalore, Kochi, Greater NCR...
# 23                                          Bangalore
# 28                                          Bangalore
# 30                         Ahmedabad, Bangalore, Pune
# 37                                          Bangalore
#
#                                              jobtitle  numberofpositions  \
# 6                                       PHP Developer                2.0
# 23             Sr iOS Developer - Objective C / Cocoa                NaN
# 28   Senio QA with a Product Based Startup, Bangalore                NaN
# 30  Test Automation Engineer ( Selenium + API Test...                2.0
# 37                                Senior Developer-bi                NaN
#
#                        payrate                   postdate site_name  \
# 6      3,00,000 - 6,50,000 P.A  2016-10-13 16:20:55 +0000       NaN
# 23  Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000       NaN
# 28    9,00,000 - 14,00,000 P.A  2016-10-13 16:20:56 +0000       NaN
# 30  Not Disclosed by Recruiter  2016-10-13 16:20:56 +0000       NaN
# 37  Not Disclosed by Recruiter  2016-10-13 16:20:56 +0000       NaN
#
#                                    skills                           uniq_id  \
# 6   IT Software - Application Programming  98f84958cd6409386e7f0c9e447b8510
# 23  IT Software - Application Programming  bf23fa0322c4af0f4d24ae7241a33d99
# 28  IT Software - Application Programming  3382a9c15d825cb9382dc5f3a1f99ce3
# 30             IT Software - QA & Testing  fb748fb77d37c9cdd15daaa68f77f95a
# 37  IT Software - Application Programming  0f469db6708503116bf996c325047bc1
#
#        split
# 6  -0.068122
# 23 -0.751303
# 28  0.493978
# 30 -1.350865
# 37 -1.292006

# %%
train.head(5).transpose()
# Out:
#                                                                     2   \
# company                            Softtech Career Infosystem Pvt. Ltd
# education            UG: Any Graduate - Any Specialization PG:Any P...
# experience                                                   4 - 8 yrs
# industry                               IT-Software / Software Services
# jobdescription       Job Description   Send me Jobs like this - as ...
# jobid                                                     101016900534
# joblocation_address                                          Bangalore
# jobtitle                                        Pl/sql Developer - SQL
# numberofpositions                                                  NaN
# payrate                                     Not Disclosed by Recruiter
# postdate                                     2016-10-13 16:20:55 +0000
# site_name                                                          NaN
# skills                           IT Software - Application Programming
# uniq_id                               c47df6f4cfdf5b46f1fd713ba61b9eba
# split                                                         0.647748
#
#                                                                     4   \
# company                     Spire Technologies and Solutions Pvt. Ltd.
# education            UG: B.Tech/B.E. - Any Specialization PG:Any Po...
# experience                                                   6 - 8 yrs
# industry                               IT-Software / Software Services
# jobdescription       Job Description   Send me Jobs like this Pleas...
# jobid                                                     120916002122
# joblocation_address                                          Bangalore
# jobtitle                               JAVA Technical Lead (6-8 yrs) -
# numberofpositions                                                    4
# payrate                                     Not Disclosed by Recruiter
# postdate                                     2016-10-13 16:20:55 +0000
# site_name                                                          NaN
# skills                           IT Software - Application Programming
# uniq_id                               a12553fc03bc7bcced8b1bb8963f97b4
# split                                                        -0.114305
#
#                                                                     5   \
# company                                PFS Web Global Services Pvt Ltd
# education            UG: B.Tech/B.E. - Any Specialization PG:MCA - ...
# experience                                                   2 - 5 yrs
# industry                               IT-Software / Software Services
# jobdescription       Job Description   Send me Jobs like this We ar...
# jobid                                                     131016005070
# joblocation_address                                          Bangalore
# jobtitle             WALK IN - As400 Developer - Pfsweb Global Serv...
# numberofpositions                                                  NaN
# payrate                                     Not Disclosed by Recruiter
# postdate                                     2016-10-13 16:20:55 +0000
# site_name                                                          NaN
# skills                           IT Software - Application Programming
# uniq_id                               8c3af9062ea835b0965779e2c7faac76
# split                                                         -0.63889
#
#                                                                     9   \
# company                                                      Accenture
# education            UG: Any Graduate - Any Specialization PG:Any P...
# experience                                                   1 - 5 yrs
# industry                               IT-Software / Software Services
# jobdescription       Job Description   Send me Jobs like this Overa...
# jobid                                                     121016901354
# joblocation_address                                          Bangalore
# jobtitle                                             German Translator
# numberofpositions                                                  NaN
# payrate                                     Not Disclosed by Recruiter
# postdate                                     2016-10-13 16:20:55 +0000
# site_name                                                          NaN
# skills                                                            ITES
# uniq_id                               7774df1c672c0b92486da8b36a721638
# split                                                          -0.2661
#
#                                                                     11
# company                    Convate hiring for Retail/e-commerce domain
# education                        UG: Any Graduate - Any Specialization
# experience                                                   4 - 8 yrs
# industry                               IT-Software / Software Services
# jobdescription       Job Description   Send me Jobs like this Greet...
# jobid                                                      61016003187
# joblocation_address                                          Bangalore
# jobtitle               Opening for Android Developer-bangalore-4-8 yrs
# numberofpositions                                                  NaN
# payrate                                     Not Disclosed by Recruiter
# postdate                                     2016-10-13 16:20:55 +0000
# site_name                                                          NaN
# skills                           IT Software - Application Programming
# uniq_id                               2657f737cb46cf289a05d6577a746976
# split                                                        -0.878506

# %%
train
# Out:
#                                                  company  \
# 2                    Softtech Career Infosystem Pvt. Ltd
# 4             Spire Technologies and Solutions Pvt. Ltd.
# 5                        PFS Web Global Services Pvt Ltd
# 9                                              Accenture
# 11           Convate hiring for Retail/e-commerce domain
# ...                                                  ...
# 21986                                Peopleton Solutions
# 21988                  Microsoft India (R and D) Pvt Ltd
# 21990  Link Tree Technologies PVT LTD hiring for CMM ...
# 21992                                       Confidential
# 21999                    Cambio Consulting India Pvt Ltd
#
#                                                education   experience  \
# 2      UG: Any Graduate - Any Specialization PG:Any P...    4 - 8 yrs
# 4      UG: B.Tech/B.E. - Any Specialization PG:Any Po...    6 - 8 yrs
# 5      UG: B.Tech/B.E. - Any Specialization PG:MCA - ...    2 - 5 yrs
# 9      UG: Any Graduate - Any Specialization PG:Any P...    1 - 5 yrs
# 11                 UG: Any Graduate - Any Specialization    4 - 8 yrs
# ...                                                  ...          ...
# 21986  UG: B.Tech/B.E. - Any Specialization PG:MCA - ...    4 - 9 yrs
# 21988  UG: B.Tech/B.E. - Computers PG:MS/M.Sc(Science...    6 - 7 yrs
# 21990  UG: Any Graduate - Any Specialization PG:Post ...   7 - 12 yrs
# 21992  UG: Any Graduate - Any Specialization Doctorat...  12 - 18 yrs
# 21999  UG: B.Tech/B.E. - Any Specialization PG:MCA - ...   5 - 10 yrs
#
#                               industry  \
# 2      IT-Software / Software Services
# 4      IT-Software / Software Services
# 5      IT-Software / Software Services
# 9      IT-Software / Software Services
# 11     IT-Software / Software Services
# ...                                ...
# 21986  IT-Software / Software Services
# 21988  IT-Software / Software Services
# 21990  IT-Software / Software Services
# 21992  IT-Software / Software Services
# 21999  IT-Software / Software Services
#
#                                           jobdescription         jobid  \
# 2      Job Description   Send me Jobs like this - as ...  101016900534
# 4      Job Description   Send me Jobs like this Pleas...  120916002122
# 5      Job Description   Send me Jobs like this We ar...  131016005070
# 9      Job Description   Send me Jobs like this Overa...  121016901354
# 11     Job Description   Send me Jobs like this Greet...   61016003187
# ...                                                  ...           ...
# 21986  Job Description   Send me Jobs like this Stron...  261116002974
# 21988  Job Description   Send me Jobs like this Job D...  241116901005
# 21990  Job Description   Send me Jobs like this Looki...  261116001071
# 21992  Job Description   Send me Jobs like this Solut...  261116900077
# 21999  Job Description   Send me Jobs like this Job d...  251116003840
#
#       joblocation_address                                           jobtitle  \
# 2               Bangalore                             Pl/sql Developer - SQL
# 4               Bangalore                    JAVA Technical Lead (6-8 yrs) -
# 5               Bangalore  WALK IN - As400 Developer - Pfsweb Global Serv...
# 9               Bangalore                                  German Translator
# 11              Bangalore    Opening for Android Developer-bangalore-4-8 yrs
# ...                   ...                                                ...
# 21986      Bangalore, NCR        SDE 2 (contact at Priyank.pal@peopleton.in)
# 21988           Bangalore                                               SDE2
# 21990           Bangalore   Urgent Placement for SAP ABAP with HCL Bangalore
# 21992           Bangalore                        Advisory Solution Architect
# 21999           Bangalore                              RF Firmware Engineers
#
#        numberofpositions                                    payrate  \
# 2                    NaN                 Not Disclosed by Recruiter
# 4                    4.0                 Not Disclosed by Recruiter
# 5                    NaN                 Not Disclosed by Recruiter
# 9                    NaN                 Not Disclosed by Recruiter
# 11                   NaN                 Not Disclosed by Recruiter
# ...                  ...                                        ...
# 21986                NaN  15,00,000 - 30,00,000 P.A. Salary is open
# 21988                NaN                 Not Disclosed by Recruiter
# 21990                NaN                 Not Disclosed by Recruiter
# 21992                NaN                 Not Disclosed by Recruiter
# 21999                NaN                  12,00,000 - 22,00,000 P.A
#
#                         postdate       site_name  \
# 2      2016-10-13 16:20:55 +0000             NaN
# 4      2016-10-13 16:20:55 +0000             NaN
# 5      2016-10-13 16:20:55 +0000             NaN
# 9      2016-10-13 16:20:55 +0000             NaN
# 11     2016-10-13 16:20:55 +0000             NaN
# ...                          ...             ...
# 21986  2016-11-25 22:47:05 +0000  www.naukri.com
# 21988  2016-11-25 22:47:05 +0000  www.naukri.com
# 21990  2016-11-25 22:47:05 +0000  www.naukri.com
# 21992  2016-11-25 22:47:05 +0000  www.naukri.com
# 21999  2016-11-25 22:47:05 +0000  www.naukri.com
#
#                                       skills  \
# 2      IT Software - Application Programming
# 4      IT Software - Application Programming
# 5      IT Software - Application Programming
# 9                                       ITES
# 11     IT Software - Application Programming
# ...                                      ...
# 21986                IT Software - eCommerce
# 21988                IT Software - eCommerce
# 21990  IT Software - Application Programming
# 21992  IT Software - Application Programming
# 21999       IT Software - System Programming
#
#                                 uniq_id     split
# 2      c47df6f4cfdf5b46f1fd713ba61b9eba  0.647748
# 4      a12553fc03bc7bcced8b1bb8963f97b4 -0.114305
# 5      8c3af9062ea835b0965779e2c7faac76 -0.638890
# 9      7774df1c672c0b92486da8b36a721638 -0.266100
# 11     2657f737cb46cf289a05d6577a746976 -0.878506
# ...                                 ...       ...
# 21986  ca542ff8b113744468b677f061bde0ec -0.169210
# 21988  a225337270ab5f885ee8af83e7b04865  1.172678
# 21990  9810d3c9e451e7374871ec1927d59111 -1.368424
# 21992  0eb70f84a1d491fb2ad7332241475741  1.138126
# 21999  74fec26df6e1c0be0171311a2f03f180  1.044336
#
# [6387 rows x 15 columns]

# %% [markdown]
# ## Job Recommendation Based on Job Title

# %%
train.columns
# Out:
# Index(['company', 'education', 'experience', 'industry', 'jobdescription',
#        'jobid', 'joblocation_address', 'jobtitle', 'numberofpositions',
#        'payrate', 'postdate', 'site_name', 'skills', 'uniq_id', 'split'],
#       dtype='object')

# %%
train.head().transpose()
# Out:
#                                                                     2   \
# company                            Softtech Career Infosystem Pvt. Ltd
# education            UG: Any Graduate - Any Specialization PG:Any P...
# experience                                                   4 - 8 yrs
# industry                               IT-Software / Software Services
# jobdescription       Job Description   Send me Jobs like this - as ...
# jobid                                                     101016900534
# joblocation_address                                          Bangalore
# jobtitle                                        Pl/sql Developer - SQL
# numberofpositions                                                  NaN
# payrate                                     Not Disclosed by Recruiter
# postdate                                     2016-10-13 16:20:55 +0000
# site_name                                                          NaN
# skills                           IT Software - Application Programming
# uniq_id                               c47df6f4cfdf5b46f1fd713ba61b9eba
# split                                                         0.647748
#
#                                                                     4   \
# company                     Spire Technologies and Solutions Pvt. Ltd.
# education            UG: B.Tech/B.E. - Any Specialization PG:Any Po...
# experience                                                   6 - 8 yrs
# industry                               IT-Software / Software Services
# jobdescription       Job Description   Send me Jobs like this Pleas...
# jobid                                                     120916002122
# joblocation_address                                          Bangalore
# jobtitle                               JAVA Technical Lead (6-8 yrs) -
# numberofpositions                                                    4
# payrate                                     Not Disclosed by Recruiter
# postdate                                     2016-10-13 16:20:55 +0000
# site_name                                                          NaN
# skills                           IT Software - Application Programming
# uniq_id                               a12553fc03bc7bcced8b1bb8963f97b4
# split                                                        -0.114305
#
#                                                                     5   \
# company                                PFS Web Global Services Pvt Ltd
# education            UG: B.Tech/B.E. - Any Specialization PG:MCA - ...
# experience                                                   2 - 5 yrs
# industry                               IT-Software / Software Services
# jobdescription       Job Description   Send me Jobs like this We ar...
# jobid                                                     131016005070
# joblocation_address                                          Bangalore
# jobtitle             WALK IN - As400 Developer - Pfsweb Global Serv...
# numberofpositions                                                  NaN
# payrate                                     Not Disclosed by Recruiter
# postdate                                     2016-10-13 16:20:55 +0000
# site_name                                                          NaN
# skills                           IT Software - Application Programming
# uniq_id                               8c3af9062ea835b0965779e2c7faac76
# split                                                         -0.63889
#
#                                                                     9   \
# company                                                      Accenture
# education            UG: Any Graduate - Any Specialization PG:Any P...
# experience                                                   1 - 5 yrs
# industry                               IT-Software / Software Services
# jobdescription       Job Description   Send me Jobs like this Overa...
# jobid                                                     121016901354
# joblocation_address                                          Bangalore
# jobtitle                                             German Translator
# numberofpositions                                                  NaN
# payrate                                     Not Disclosed by Recruiter
# postdate                                     2016-10-13 16:20:55 +0000
# site_name                                                          NaN
# skills                                                            ITES
# uniq_id                               7774df1c672c0b92486da8b36a721638
# split                                                          -0.2661
#
#                                                                     11
# company                    Convate hiring for Retail/e-commerce domain
# education                        UG: Any Graduate - Any Specialization
# experience                                                   4 - 8 yrs
# industry                               IT-Software / Software Services
# jobdescription       Job Description   Send me Jobs like this Greet...
# jobid                                                      61016003187
# joblocation_address                                          Bangalore
# jobtitle               Opening for Android Developer-bangalore-4-8 yrs
# numberofpositions                                                  NaN
# payrate                                     Not Disclosed by Recruiter
# postdate                                     2016-10-13 16:20:55 +0000
# site_name                                                          NaN
# skills                           IT Software - Application Programming
# uniq_id                               2657f737cb46cf289a05d6577a746976
# split                                                        -0.878506

# %%
train['jobtitle'] = train['jobtitle'].fillna('')
train['jobdescription'] = train['jobdescription'].fillna('')
#jobs_US_base_line['Requirements'] = jobs_US_base_line['Requirements'].fillna('')

train['jobdescription'] = train['jobtitle'] + train['jobdescription']

# %%
tf = TfidfVectorizer(ngram_range=(1, 2),min_df=0, stop_words='english')
tfidf_matrix = tf.fit_transform(train['jobdescription'])

# %%
tfidf_matrix.shape
# Out:
# (6387, 410269)

# %%
# http://scikit-learn.org/stable/modules/metrics.html#linear-kernel
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
cosine_sim[0]
# Out:
# array([1.        , 0.02118194, 0.01565881, ..., 0.0276533 , 0.02820985,
#        0.01674215])

# %%
train = train.reset_index()
titles = train['jobtitle']
indices = pd.Series(train.index, index=train['jobtitle'])
#indices.head(2)

# %%
def get_recommendations(title):
    idx = indices[title]
    #print (idx)
    sim_scores = list(enumerate(cosine_sim[idx]))
    #print (sim_scores)
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    job_indices = [i[0] for i in sim_scores]
    return titles.iloc[job_indices]

# %%
get_recommendations('Pl/sql Developer - SQL').head(10)
# Out:
# 0                         Pl/sql Developer - SQL
# 3773                   Pl/sql Developer - Mumbai
# 1369                   ETL Tester - Sql/teradata
# 3072    Oracle BRM Developer - C/shell Scripting
# 72      Salesforce Developer - Apex/visual Force
# 3079                Hadoop Developer - Java/j2ee
# 6350                 Windows Engineer - Embedded
# 3111      Java/j2ee Developer - Spring/hibernate
# 3094                                 UX Designer
# 1567          UI Developer - Html/css/javascript
# Name: jobtitle, dtype: object

# %%
get_recommendations('German Translator').head(10)
# Out:
# 3                                       German Translator
# 481                          Salesforce.com Professionals
# 7                                       Revenue Assurance
# 15                                           Call Quality
# 11                                              Analytics
# 285     Sap-extended Wareh.&logis.- Logis. Serv. Provi...
# 6308                    Java Enterprise Edition Developer
# 347              PTC (parametric Technology Corporation)-
# 398                            Human Performance Lab Lead
# 469                         Recruitment Associate Manager
# Name: jobtitle, dtype: object

# %%
get_recommendations('Opening for Android Developer-bangalore-4-8 yrs').head(10)
# Out:
# 4         Opening for Android Developer-bangalore-4-8 yrs
# 179     Immediate Joinee for WAS for top Retail Domain...
# 28      Opening for Hadoop Developers-product Developm...
# 253                   Android Developer,3.5yrs+,bangalore
# 904     Immediate Opening for Android Application Deve...
# 6213    Android Developer -2+ Years Experience (locati...
# 852                                     Android Developer
# 2552                Android Developer - Immediate Joining
# 4930                             Project Engineer C#, WPF
# 2341    Urgent :-immediate Req- Android Developer,good...
# Name: jobtitle, dtype: object

# %%
get_recommendations('JAVA Technical Lead (6-8 yrs) -').head(10)
# Out:
# 1                         JAVA Technical Lead (6-8 yrs) -
# 984                                   Java Technical Lead
# 2037                    Big Data Technical Architect/Lead
# 5870           Senior Tech Lead/architect - Big Data/java
# 3354                                     Product Engineer
# 6301                                  Java Technical lead
# 3372                                 Sr. Product Engineer
# 4163    Hiring Big Data Experts for a Product Dev Co -...
# 90                                          Lead Engineer
# 5208                                 Angular.js Developer
# Name: jobtitle, dtype: object

# %% [markdown]
# ## Alternative approach
#
# #### Find out similar users -- Find out for which jobs they have applied -- suggest those job to the other users who shared similar user profile.
#
# We are finding put similar user profile based on their education and total years of experience.
# * We will get to 10 similar users.
# * We will find our which are the jobs for which these users have applied
# * We take an union of these jobs and recommend the jobs all these user base

# %%
train.head()
# Out:
#    index                                      company  \
# 0      2          Softtech Career Infosystem Pvt. Ltd
# 1      4   Spire Technologies and Solutions Pvt. Ltd.
# 2      5              PFS Web Global Services Pvt Ltd
# 3      9                                    Accenture
# 4     11  Convate hiring for Retail/e-commerce domain
#
#                                            education experience  \
# 0  UG: Any Graduate - Any Specialization PG:Any P...  4 - 8 yrs
# 1  UG: B.Tech/B.E. - Any Specialization PG:Any Po...  6 - 8 yrs
# 2  UG: B.Tech/B.E. - Any Specialization PG:MCA - ...  2 - 5 yrs
# 3  UG: Any Graduate - Any Specialization PG:Any P...  1 - 5 yrs
# 4              UG: Any Graduate - Any Specialization  4 - 8 yrs
#
#                           industry  \
# 0  IT-Software / Software Services
# 1  IT-Software / Software Services
# 2  IT-Software / Software Services
# 3  IT-Software / Software Services
# 4  IT-Software / Software Services
#
#                                       jobdescription         jobid  \
# 0  Pl/sql Developer - SQLJob Description   Send m...  101016900534
# 1  JAVA Technical Lead (6-8 yrs) -Job Description...  120916002122
# 2  WALK IN - As400 Developer - Pfsweb Global Serv...  131016005070
# 3  German TranslatorJob Description   Send me Job...  121016901354
# 4  Opening for Android Developer-bangalore-4-8 yr...   61016003187
#
#   joblocation_address                                           jobtitle  \
# 0           Bangalore                             Pl/sql Developer - SQL
# 1           Bangalore                    JAVA Technical Lead (6-8 yrs) -
# 2           Bangalore  WALK IN - As400 Developer - Pfsweb Global Serv...
# 3           Bangalore                                  German Translator
# 4           Bangalore    Opening for Android Developer-bangalore-4-8 yrs
#
#    numberofpositions                     payrate                   postdate  \
# 0                NaN  Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000
# 1                4.0  Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000
# 2                NaN  Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000
# 3                NaN  Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000
# 4                NaN  Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000
#
#   site_name                                 skills  \
# 0       NaN  IT Software - Application Programming
# 1       NaN  IT Software - Application Programming
# 2       NaN  IT Software - Application Programming
# 3       NaN                                   ITES
# 4       NaN  IT Software - Application Programming
#
#                             uniq_id     split
# 0  c47df6f4cfdf5b46f1fd713ba61b9eba  0.647748
# 1  a12553fc03bc7bcced8b1bb8963f97b4 -0.114305
# 2  8c3af9062ea835b0965779e2c7faac76 -0.638890
# 3  7774df1c672c0b92486da8b36a721638 -0.266100
# 4  2657f737cb46cf289a05d6577a746976 -0.878506

# %%
user_based_approach_B = train.loc[train['joblocation_address']=='Bangalore']

# %%
user_based_approach = user_based_approach_B.iloc[0:10000,:]

# %%
user_based_approach.head()
# Out:
#    index                                      company  \
# 0      2          Softtech Career Infosystem Pvt. Ltd
# 1      4   Spire Technologies and Solutions Pvt. Ltd.
# 2      5              PFS Web Global Services Pvt Ltd
# 3      9                                    Accenture
# 4     11  Convate hiring for Retail/e-commerce domain
#
#                                            education experience  \
# 0  UG: Any Graduate - Any Specialization PG:Any P...  4 - 8 yrs
# 1  UG: B.Tech/B.E. - Any Specialization PG:Any Po...  6 - 8 yrs
# 2  UG: B.Tech/B.E. - Any Specialization PG:MCA - ...  2 - 5 yrs
# 3  UG: Any Graduate - Any Specialization PG:Any P...  1 - 5 yrs
# 4              UG: Any Graduate - Any Specialization  4 - 8 yrs
#
#                           industry  \
# 0  IT-Software / Software Services
# 1  IT-Software / Software Services
# 2  IT-Software / Software Services
# 3  IT-Software / Software Services
# 4  IT-Software / Software Services
#
#                                       jobdescription         jobid  \
# 0  Pl/sql Developer - SQLJob Description   Send m...  101016900534
# 1  JAVA Technical Lead (6-8 yrs) -Job Description...  120916002122
# 2  WALK IN - As400 Developer - Pfsweb Global Serv...  131016005070
# 3  German TranslatorJob Description   Send me Job...  121016901354
# 4  Opening for Android Developer-bangalore-4-8 yr...   61016003187
#
#   joblocation_address                                           jobtitle  \
# 0           Bangalore                             Pl/sql Developer - SQL
# 1           Bangalore                    JAVA Technical Lead (6-8 yrs) -
# 2           Bangalore  WALK IN - As400 Developer - Pfsweb Global Serv...
# 3           Bangalore                                  German Translator
# 4           Bangalore    Opening for Android Developer-bangalore-4-8 yrs
#
#    numberofpositions                     payrate                   postdate  \
# 0                NaN  Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000
# 1                4.0  Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000
# 2                NaN  Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000
# 3                NaN  Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000
# 4                NaN  Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000
#
#   site_name                                 skills  \
# 0       NaN  IT Software - Application Programming
# 1       NaN  IT Software - Application Programming
# 2       NaN  IT Software - Application Programming
# 3       NaN                                   ITES
# 4       NaN  IT Software - Application Programming
#
#                             uniq_id     split
# 0  c47df6f4cfdf5b46f1fd713ba61b9eba  0.647748
# 1  a12553fc03bc7bcced8b1bb8963f97b4 -0.114305
# 2  8c3af9062ea835b0965779e2c7faac76 -0.638890
# 3  7774df1c672c0b92486da8b36a721638 -0.266100
# 4  2657f737cb46cf289a05d6577a746976 -0.878506

# %%
user_based_approach['education'] = user_based_approach['education'].fillna('')
user_based_approach['experience'] = str(user_based_approach['experience'].fillna(''))

user_based_approach['education'] = user_based_approach['education'] + user_based_approach['experience']

# %%
tf = TfidfVectorizer(ngram_range=(1, 2),min_df=0, stop_words='english')
tfidf_matrix = tf.fit_transform(user_based_approach['education'])

# %%
tfidf_matrix.shape
# Out:
# (1677, 417)

# %%
# http://scikit-learn.org/stable/modules/metrics.html#linear-kernel
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
cosine_sim[0]
# Out:
# array([1.        , 0.63033656, 0.46554876, ..., 0.87851187, 0.93595402,
#        0.61883365])

# %%
userid = user_based_approach['level_0']
indices = pd.Series(user_based_approach.index, index=user_based_approach['level_0'])
#indices.head(2)

# %%
def get_recommendations_userwise(userid):
    idx = indices[userid]
    #print (idx)
    sim_scores = list(enumerate(cosine_sim[idx]))
    #print (sim_scores)
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    user_indices = [i[0] for i in sim_scores]
    #print (user_indices)
    return user_indices[0:11]

# %%
print ("-----Top 10 Similar users with userId: 123------")
get_recommendations_userwise(123)
# Out:
# -----Top 10 Similar users with userId: 123------
# [9, 14, 23, 25, 31, 36, 37, 38, 42, 45, 47]

# %%
train
# Out:
#       index                                            company  \
# 0         2                Softtech Career Infosystem Pvt. Ltd
# 1         4         Spire Technologies and Solutions Pvt. Ltd.
# 2         5                    PFS Web Global Services Pvt Ltd
# 3         9                                          Accenture
# 4        11        Convate hiring for Retail/e-commerce domain
# ...     ...                                                ...
# 6382  21986                                Peopleton Solutions
# 6383  21988                  Microsoft India (R and D) Pvt Ltd
# 6384  21990  Link Tree Technologies PVT LTD hiring for CMM ...
# 6385  21992                                       Confidential
# 6386  21999                    Cambio Consulting India Pvt Ltd
#
#                                               education   experience  \
# 0     UG: Any Graduate - Any Specialization PG:Any P...    4 - 8 yrs
# 1     UG: B.Tech/B.E. - Any Specialization PG:Any Po...    6 - 8 yrs
# 2     UG: B.Tech/B.E. - Any Specialization PG:MCA - ...    2 - 5 yrs
# 3     UG: Any Graduate - Any Specialization PG:Any P...    1 - 5 yrs
# 4                 UG: Any Graduate - Any Specialization    4 - 8 yrs
# ...                                                 ...          ...
# 6382  UG: B.Tech/B.E. - Any Specialization PG:MCA - ...    4 - 9 yrs
# 6383  UG: B.Tech/B.E. - Computers PG:MS/M.Sc(Science...    6 - 7 yrs
# 6384  UG: Any Graduate - Any Specialization PG:Post ...   7 - 12 yrs
# 6385  UG: Any Graduate - Any Specialization Doctorat...  12 - 18 yrs
# 6386  UG: B.Tech/B.E. - Any Specialization PG:MCA - ...   5 - 10 yrs
#
#                              industry  \
# 0     IT-Software / Software Services
# 1     IT-Software / Software Services
# 2     IT-Software / Software Services
# 3     IT-Software / Software Services
# 4     IT-Software / Software Services
# ...                               ...
# 6382  IT-Software / Software Services
# 6383  IT-Software / Software Services
# 6384  IT-Software / Software Services
# 6385  IT-Software / Software Services
# 6386  IT-Software / Software Services
#
#                                          jobdescription         jobid  \
# 0     Pl/sql Developer - SQLJob Description   Send m...  101016900534
# 1     JAVA Technical Lead (6-8 yrs) -Job Description...  120916002122
# 2     WALK IN - As400 Developer - Pfsweb Global Serv...  131016005070
# 3     German TranslatorJob Description   Send me Job...  121016901354
# 4     Opening for Android Developer-bangalore-4-8 yr...   61016003187
# ...                                                 ...           ...
# 6382  SDE 2 (contact at Priyank.pal@peopleton.in)Job...  261116002974
# 6383  SDE2Job Description   Send me Jobs like this J...  241116901005
# 6384  Urgent Placement for SAP ABAP with HCL Bangalo...  261116001071
# 6385  Advisory Solution ArchitectJob Description   S...  261116900077
# 6386  RF Firmware EngineersJob Description   Send me...  251116003840
#
#      joblocation_address                                           jobtitle  \
# 0              Bangalore                             Pl/sql Developer - SQL
# 1              Bangalore                    JAVA Technical Lead (6-8 yrs) -
# 2              Bangalore  WALK IN - As400 Developer - Pfsweb Global Serv...
# 3              Bangalore                                  German Translator
# 4              Bangalore    Opening for Android Developer-bangalore-4-8 yrs
# ...                  ...                                                ...
# 6382      Bangalore, NCR        SDE 2 (contact at Priyank.pal@peopleton.in)
# 6383           Bangalore                                               SDE2
# 6384           Bangalore   Urgent Placement for SAP ABAP with HCL Bangalore
# 6385           Bangalore                        Advisory Solution Architect
# 6386           Bangalore                              RF Firmware Engineers
#
#       numberofpositions                                    payrate  \
# 0                   NaN                 Not Disclosed by Recruiter
# 1                   4.0                 Not Disclosed by Recruiter
# 2                   NaN                 Not Disclosed by Recruiter
# 3                   NaN                 Not Disclosed by Recruiter
# 4                   NaN                 Not Disclosed by Recruiter
# ...                 ...                                        ...
# 6382                NaN  15,00,000 - 30,00,000 P.A. Salary is open
# 6383                NaN                 Not Disclosed by Recruiter
# 6384                NaN                 Not Disclosed by Recruiter
# 6385                NaN                 Not Disclosed by Recruiter
# 6386                NaN                  12,00,000 - 22,00,000 P.A
#
#                        postdate       site_name  \
# 0     2016-10-13 16:20:55 +0000             NaN
# 1     2016-10-13 16:20:55 +0000             NaN
# 2     2016-10-13 16:20:55 +0000             NaN
# 3     2016-10-13 16:20:55 +0000             NaN
# 4     2016-10-13 16:20:55 +0000             NaN
# ...                         ...             ...
# 6382  2016-11-25 22:47:05 +0000  www.naukri.com
# 6383  2016-11-25 22:47:05 +0000  www.naukri.com
# 6384  2016-11-25 22:47:05 +0000  www.naukri.com
# 6385  2016-11-25 22:47:05 +0000  www.naukri.com
# 6386  2016-11-25 22:47:05 +0000  www.naukri.com
#
#                                      skills                           uniq_id  \
# 0     IT Software - Application Programming  c47df6f4cfdf5b46f1fd713ba61b9eba
# 1     IT Software - Application Programming  a12553fc03bc7bcced8b1bb8963f97b4
# 2     IT Software - Application Programming  8c3af9062ea835b0965779e2c7faac76
# 3                                      ITES  7774df1c672c0b92486da8b36a721638
# 4     IT Software - Application Programming  2657f737cb46cf289a05d6577a746976
# ...                                     ...                               ...
# 6382                IT Software - eCommerce  ca542ff8b113744468b677f061bde0ec
# 6383                IT Software - eCommerce  a225337270ab5f885ee8af83e7b04865
# 6384  IT Software - Application Programming  9810d3c9e451e7374871ec1927d59111
# 6385  IT Software - Application Programming  0eb70f84a1d491fb2ad7332241475741
# 6386       IT Software - System Programming  74fec26df6e1c0be0171311a2f03f180
#
#          split
# 0     0.647748
# 1    -0.114305
# 2    -0.638890
# 3    -0.266100
# 4    -0.878506
# ...        ...
# 6382 -0.169210
# 6383  1.172678
# 6384 -1.368424
# 6385  1.138126
# 6386  1.044336
#
# [6387 rows x 16 columns]

# %%
def get_job_id(usrid_list):
    jobs_userwise = train['index'].isin(usrid_list) #
    df1 = pd.DataFrame(data = train[jobs_userwise], columns=['jobid'])
    joblist = df1['jobid'].tolist()
    Job_list = train['jobid'].isin(joblist) #[1083186, 516837, 507614, 754917, 686406, 1058896, 335132])
    df_temp = pd.DataFrame(data = train[Job_list], columns=['jobid','jobtitle','jobdescription','joblocation_address'])
    return df_temp

# %%
get_job_id(get_recommendations_userwise(10))
# Out:
#            jobid                                           jobtitle  \
# 12  160316902471              Java Developer - Spring/mvc/hibernate
# 41  150716001591  Associate Software Engineer And Testing Jobs I...
# 51  200716005010  Available Part time / full time work at Top M....
#
#                                        jobdescription  \
# 12  Java Developer - Spring/mvc/hibernateJob Descr...
# 41  Associate Software Engineer And Testing Jobs I...
# 51  Available Part time / full time work at Top M....
#
#                                   joblocation_address
# 12                                          Bangalore
# 41                               Bangalore, Hyderabad
# 51  NCR, Hyderabad, Dehradun, Mumbai, Bangalore, J...

# %%
print ("-----Top 10 Similar users with userId: 47------")
get_recommendations_userwise(47)
# Out:
# -----Top 10 Similar users with userId: 47------
# [9, 14, 23, 25, 31, 36, 37, 38, 42, 45, 47]

# %%
get_job_id(get_recommendations_userwise(47))
# Out:
#            jobid                                           jobtitle  \
# 3   121016901354                                  German Translator
# 7   121016901343                                  Revenue Assurance
# 14  131016004798  Good Opportunity for Oracle DBA - Bangalore Lo...
# 17   81016900152    WLAN Device Driver Development Engineer - Linux
# 20  220116901982                Developer - SQL Bi/cosmos/sql Azure
#
#                                        jobdescription joblocation_address
# 3   German TranslatorJob Description   Send me Job...           Bangalore
# 7   Revenue AssuranceJob Description   Send me Job...           Bangalore
# 14  Good Opportunity for Oracle DBA - Bangalore Lo...           Bangalore
# 17  WLAN Device Driver Development Engineer - Linu...           Bangalore
# 20  Developer - SQL Bi/cosmos/sql AzureJob Descrip...           Bangalore
